# %%
import pandas as pd

# %%
df = pd.read_csv (r'./bestsellers with categories.csv', parse_dates=True)

# we want the display the mean of the reviews for each year
data_per_year = df[['Name', "Year", "User Rating"]].groupby('User Rating', as_index=False).mean()
data_per_year = data_per_year.set_index("Year")
data_per_year.sort_values(["Year", "User Rating"], inplace=True)

# this will convert the index type to int from float
data_per_year.index = data_per_year.index.map(int)
data_per_year.head()
# Out:
#       User Rating
# Year
# 2011          4.2
# 2012          3.3
# 2012          3.8
# 2012          4.4
# 2012          4.0
# 2013          4.1
# 2013          4.6
# 2013          3.9
# 2013          4.5
# 2013          4.3
# 2013          4.7
# 2014          4.8
# 2015          3.6
# 2016          4.9
#       User Rating
# Year
# 2011          4.2
# 2012          3.3
# 2012          3.8
# 2012          4.4
# 2012          4.0

# %%
import matplotlib.pyplot as plt

# plot the mean ratings per year
data_per_year.keys()
data_per_year["User Rating"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
pip install chart_studio
pip install cufflinks
# Out:
# ...
#   Using cached chart_studio-1.1.0-py3-none-any.whl (64 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# will plot the amount of non-fiction and fiction books per year
import plotly.express as px

fig = px.scatter(genres_per_year, x="Year", y="Genre", color="Genre",
    size=genres_per_year['Name'], size_max=32, log_x=False)


fig.update_layout(legend=dict(
    orientation="h",
    yanchor="bottom",
    y=1.02,
    xanchor="right",
    x=1
))

fig.show()
# Out:
# <div>                            <div id="4d6e26df-a5e9-41f2-83dc-d80f7fafd6b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d6e26df-a5e9-41f2-83dc-d80f7fafd6b3")) {                    Plotly.newPlot(                        "4d6e26df-a5e9-41f2-83dc-d80f7fafd6b3",                        [{"hovertemplate": "Genre=%{y}<br>Year=%{x}<br>Name=%{marker.size}<extra></extra>", "legendgroup": "Fiction", "marker": {"color": "#636efa", "size": [24, 20, 21, 21, 24, 29, 17, 19, 24, 21, 20], "sizemode": "area", "sizeref": 0.0322265625, "symbol": "circle"}, "mode": "markers", "name": "Fiction", "orientation": "h", "showlegend": true, "type": "scatter", "x": [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": ["Fiction", "Ficti
# ...
